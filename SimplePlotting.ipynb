# %%
a = 1

# %% [markdown]
# Du texte

# %%
from nilearn.datasets import fetch_icbm152_2009

# %%
fetch_icbm152_2009?

# %%
mnitemp = fetch_icbm152_2009()
# Out:
# Dataset created in /homes/nfarrugi/nilearn_data/icbm152_2009
#
# ...
# Downloaded 63116438 of 63116438 bytes (100.0%,    0.0s remaining) ...done. (72 seconds, 1 min)
# Extracting data from /homes/nfarrugi/nilearn_data/icbm152_2009/1356a5d78c4e5f06f302cffd72b32241/mni_icbm152_nlin_sym_09a_nifti.zip..... done.

# %%
mnitemp['t1']
# Out:
# '/homes/nfarrugi/nilearn_data/icbm152_2009/mni_icbm152_nlin_sym_09a/mni_icbm152_t1_tal_nlin_sym_09a.nii'

# %%
import nilearn.plotting as niplt

# %%
# %matplotlib inline

# %%
niplt.plot_anat(mnitemp['t1'])
